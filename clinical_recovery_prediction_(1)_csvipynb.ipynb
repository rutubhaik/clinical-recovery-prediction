# %% [markdown]
# <a href="https://colab.research.google.com/github/TanujaBhalerao77-crypto/clinical-recovery-prediction/blob/main/clinical_recovery_prediction_(1)_csvipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/clinical_recovery_linear_regression_dataset (1) (1).csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Drug_Dosage_mg  300 non-null    float64
#  1   Recovery_Days   300 non-null    float64
# dtypes: float64(2)
# memory usage: 4.8 KB

# %%
df.head()
# Out:
#    Drug_Dosage_mg  Recovery_Days
# 0          106.18          21.64
# 1          192.61          12.64
# 2          159.80          23.65
# 3          139.80          20.72
# 4           73.40          18.05

# %%
df.columns
# Out:
# Index(['Drug_Dosage_mg', 'Recovery_Days'], dtype='object')

# %%
df.head(10)
# Out:
#    Drug_Dosage_mg  Recovery_Days
# 0          106.18          21.64
# 1          192.61          12.64
# 2          159.80          23.65
# 3          139.80          20.72
# 4           73.40          18.05
# 5           73.40          24.69
# 6           58.71          23.32
# 7          179.93          18.16
# 8          140.17          16.41
# 9          156.21          17.16

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter (df['Drug_Dosage_mg'],df['Recovery_Days'])
plt.xlabel('drug dosage')
plt.ylabel('recovery days')
plt.show()

# %% [markdown]
# plt.plot (df['Drug_Dosage_mg'],df['Recovery_Days'])
# plt.xlabel('drug dosage')
# plt.ylabel('recovery days')
# plt.show()

# %%
plt.bar (df['Drug_Dosage_mg'],df['Recovery_Days'])
plt.xlabel('drug dosage')
plt.ylabel('recovery days')
plt.show()

# %%
plt.hist(df['Drug_Dosage_mg'])
plt.xlabel('drug dosage')
plt.ylabel('frequency')
plt.show()

# %%
plt.pie(df['Recovery_Days'], autopct='%1.1f%%')
plt.show()

# %%
#spliting data into input and output

# %%
x=df['Drug_Dosage_mg']
y=df['Recovery_Days']

# %%
x
# Out:
# 0      106.18
# 1      192.61
# 2      159.80
# 3      139.80
# 4       73.40
#         ...
# 295    128.34
# 296    165.50
# 297     82.37
# 298    143.43
# 299     62.80
# Name: Drug_Dosage_mg, Length: 300, dtype: float64

# %%
y
# Out:
# 0      21.64
# 1      12.64
# 2      23.65
# 3      20.72
# 4      18.05
#        ...
# 295    19.88
# 296    17.54
# 297    20.70
# 298    20.44
# 299    19.99
# Name: Recovery_Days, Length: 300, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (240,)

# %%
x_test.shape
# Out:
# (60,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train.to_frame(), y_train)
# Out:
# LinearRegression()

# %%
predict = model.predict(x_test.to_frame())

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(y_test, predict)

# %%
print(mae)
# Out:
# 1.970047209812255

# %%
Tanuja = [[150]]

# %%
model.predict(Tanuja)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([18.2028603])

# %%
print(Tanuja)
# Out:
# [[150]]
